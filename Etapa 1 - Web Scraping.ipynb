# %% [markdown]
# ***Etapa 1 - Web Scraping***

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importando as Bibliotecas

# %%
from tqdm import tqdm
import string
import sys
from urllib.request import urlopen
import nltk
from bs4 import BeautifulSoup
import os

# %% [markdown]
# URL alvo para Web Scrapping

# %%
url = 'https://www.letras.mus.br/'

# %% [markdown]
# Coleta dos Links de letras de músicas de uma banda

# %%
  def get_lyrics(band):
    try:
      print('Obtendo links/músicas')
      #Listas com valores únicos
      ctrl_page = set()

      #https://www.letras.mus.br/coral-kemuel/
      #https://www.letras.mus.br/fernandinho/
      #https://www.letras.mus.br/roupa-nova/
      #https://www.letras.mus.br/legiao-urbana/
      #https://www.letras.mus.br/guns-n-roses/
      #https://www.letras.mus.br/aerosmith/
      html = urlopen(f"{url}/{band}")

      #Parser das Tags HTML
      bs = BeautifulSoup(html, 'html.parser')

      #Neste momento estamos filtrando as tags do tipo <a> que estão contidas na tag <ol> da página
      for link in bs.find('ol', {'class': 'cnt-list cnt-list--num -flex-col-2 js-song-list'}).find_all('a'):
            if 'href' in link.attrs:
                #Adicionando as páginas que contém a letra de música em uma lista
                ctrl_page.add(f"{link.attrs['href']}")
        
      for lyrics in ctrl_page:
            #Chamar Função pra ler a sub-página que contém as letras completas, além do nome da música
            get_music(band,lyrics)
            
    except Exception as e:
        print(f'Ocorreu algum erro ao tentar acessar o site. {e}')

# %%
def get_lyrics(band):
    try:
        print('Obtendo links/músicas')
        #Lista, com valores únicos
        ctrl_page = set()
        
        #https://www.letras.mus.br/coral-kemuel/
        #https://www.letras.mus.br/fernandinho/
        #https://www.letras.mus.br/roupa-nova/
        #https://www.letras.mus.br/legiao-urbana/
        #https://www.letras.mus.br/guns-n-roses/
        #https://www.letras.mus.br/aerosmith/
        html = urlopen(f"{url}/{band}")
        
        #Parser das tags HTML
        bs = BeautifulSoup(html, 'html.parser')
        
        #Neste momento estamos filtrando as tags do tipo <a> que estão contidas na tag <ol> da página
        for link in bs.find('ol', {'class': 'cnt-list cnt-list--num -flex-col-2 js-song-list'}).find_all('a'):
            if 'href' in link.attrs:
                #Adicionando as páginas que contém a letra de música em uma lista
                ctrl_page.add(f"{link.attrs['href']}")
        
        for lyrics in ctrl_page:
            #Chamar Função pra ler a sub-página que contém as letras completas, além do nome da música
            get_music(band,lyrics)
            
    except Exception as e:
        print(f'Ocorreu algum erro ao tentar acessar o site. {e}')

# %% [markdown]
# Captura Todas as Músicas de uma Banda
#
# Captura todas as músicas de uma banda, grupo ou artista a partir da página www.letras.com.br/[banda/nome_da_música].

# %%
  def get_music(band, new_page):
    music = ''
    print(band)
    try:
        #lendo as letras completas
        html = urlopen(f"{url}/{new_page}")
        #parser novamente com a página html lida
        bs = BeautifulSoup(html, 'html.parser')
        
        #Estamos lendo os versos que estão separados por tags <p>
        #posteriormente nós limpamos e agrupamos a letra.
        for verse in tqdm(bs.find('div', {'class': 'cnt-letra p402_premium'}).find_all('p')):
            music += ' '.join(verse.stripped_strings)
            music += ' '
            
        
        #coleta do título da música na tag <div> com a class 'cnt-head_title'
        title_music = bs.find('div', {'class': 'cnt-head_title'}).find_all('h1')[0]
        title_music = ' '.join(title_music.stripped_strings) 
            
        #Salvando estas informações
        save_lyrics(band, music, title_music)
        
        print("Letra Capturada : " + title_music)   
    except Exception as e:
        print(f'Ocorreu algum erro ao tentar acessar o site. {e}')

# %% [markdown]
# Salva letra da Música em Disco
#
# Salva a letra de música em disco no formato .txt contando o padrão '**band$title_music**.txt'

# %%
  def save_lyrics(band, music, title_music):

    plain_text = music.lower()

    try:
      print(plain_text, file=open(f'/content/drive/My Drive/Trabalho_DSD/data/{band}${title_music}.txt', 'w'))

    except Exception as e:
      print(f'Ocorreu algum erro ao tentar gravar o arquivo. {e}')

# %% [markdown]
# Capturando Letras de Músicas

# %%
  get_lyrics("coral-kemuel")
  get_lyrics("fernandinho")
  get_lyrics("roupa-nova")
  get_lyrics("legiao-urbana")
  get_lyrics("guns-n-roses")
  get_lyrics("aerosmith")
# Out:
# Obtendo links/músicas
# coral-kemuel
# 100%|██████████| 7/7 [00:00<00:00, 6308.58it/s]
# Letra Capturada : Eu Te Louvarei
# coral-kemuel
# 100%|██████████| 7/7 [00:00<00:00, 3975.64it/s]
# Letra Capturada : Oceanos (Oceans)
# coral-kemuel
# 100%|██████████| 10/10 [00:00<00:00, 9852.72it/s]
# Letra Capturada : O Teu Amor
# coral-kemuel
# 100%|██████████| 13/13 [00:00<00:00, 9343.03it/s]
# Letra Capturada : Me Lembro
# coral-kemuel
# 100%|██████████| 9/9 [00:00<00:00, 10660.47it/s]
# Ocorreu algum erro ao tentar gravar o arquivo. [Errno 2] No such file or directory: '/content/drive/My Drive/Trabalho_DSD/data/coral-kemuel$Cadeias Quebrar / As Trevas Estremecem.txt'
# Letra Capturada : Cadeias Quebrar / As Trevas Estremecem
# coral-kemuel
# 100%|██████████| 6/6 [00:00<00:00, 2797.76it/s]
# Letra Capturada : Canta Minh'Alma
# coral-kemuel
# 100%|██████████| 9/9 [00:00<00:00, 9923.43it/s]
# 100%|██████████| 8/8 [00:00<00:00, 8462.66it/s]
# Letra Capturada : Jericó
# coral-kemuel
# Letra Capturada : Faça Morada
# coral-kemuel
# 100%|██████████| 5/5 [00:00<00:00, 1850.32it/s]
# Letra Capturada : Reunimo-nos Aqui
# coral-kemuel
# 100%|██████████| 13/13 [00:00<00:00, 5482.75it/s]
# Letra Capturada : Ressuscitou
# coral-kemuel
# 100%|██████████| 9/9 [00:00<00:00, 2407.91it/s]
# Letra Capturada : Não Vou Desistir
# coral-kemuel
# 100%|██████████| 9/9 [00:00<00:00, 9043.78it/s]
# Letra Capturada : Me Lembro (part. Gabriela Rocha)
# coral-kemuel
# 100%|██████████| 8/8 [00:00<00:00, 8365.60it/s]
# Letra Capturada : Eu Também (100 Bilhões X)
# coral-kemuel
# 100%|██████████| 8/8 [00:00<00:00, 9642.08it/s]
# Letra Capturada : Perfeito Amor
# coral-kemuel
# 100%|██████████| 15/15 [00:00<00:00, 10132.80it/s]
# 100%|██████████| 6/6 [00:00<00:00, 2228.05it/s]
# Letra Capturada : Algo Novo (part. Lukas Agustinho)
# coral-kemuel
# Letra Capturada : Em Fervente Oração
# coral-kemuel
# 100%|██████████| 16/16 [00:00<00:00, 12710.01it/s]
# Letra Capturada : Oh, Quão Lindo Esse Nome É
# coral-kemuel
# 100%|██████████| 18/18 [00:00<00:00, 10575.36it/s]
# Letra Capturada : Aba (part. Ton Carfi)
# coral-kemuel
# 100%|██████████| 11/11 [00:00<00:00, 7607.15it/s]
# Letra Capturada : Ele Vem
# coral-kemuel
# 100%|██████████| 12/12 [00:00<00:00, 11726.85it/s]
# Letra Capturada : Carta de Amor (part. Rebeca Carvalho)
# Obtendo links/músicas
# 100%|██████████| 15/15 [00:00<00:00, 16328.72it/s]
# fernandinho
# Letra Capturada : Nada Além do Sangue
# fernandinho
# 100%|██████████| 12/12 [00:00<00:00, 8732.07it/s]
# Letra Capturada : Batiza-me
# fernandinho
# 100%|██████████| 8/8 [00:00<00:00, 23045.63it/s]
# 100%|██████████| 7/7 [00:00<00:00, 1114.28it/s]
# Letra Capturada : Te Adorar (part. Aline Barros)
# fernandinho
# Letra Capturada : Uma Nova História
# fernandinho
# 100%|██████████| 9/9 [00:00<00:00, 23359.37it/s]
# Letra Capturada : Grandes Coisas
# fernandinho
# 100%|██████████| 19/19 [00:00<00:00, 5060.44it/s]
# Letra Capturada : Deus Não Está Morto (God's Not Dead)
# fernandinho
# 100%|██████████| 5/5 [00:00<00:00, 1103.94it/s]
# Letra Capturada : Seu Sangue
# fernandinho
# 100%|██████████| 4/4 [00:00<00:00, 2337.64it/s]
# 100%|██████████| 9/9 [00:00<00:00, 1888.85it/s]
# Letra Capturada : Ainda Que a Figueira
# fernandinho
# 100%|██████████| 7/7 [00:00<00:00, 26812.90it/s]
# Letra Capturada : Não Mais Escravos
# fernandinho
# Letra Capturada : Uma Coisa Peço Ao Senhor
# fernandinho
# 100%|██████████| 15/15 [00:00<00:00, 2823.56it/s]
# Letra Capturada : Yeshua (part. Heloisa Rosa)
# fernandinho
# 100%|██████████| 6/6 [00:00<00:00, 12384.76it/s]
# Letra Capturada : Jesus, Filho de Deus
# fernandinho
# 100%|██████████| 6/6 [00:00<00:00, 4561.51it/s]
# 100%|██████████| 16/16 [00:00<00:00, 37744.02it/s]
# Letra Capturada : Todas As Coisas
# fernandinho
# 100%|██████████| 4/4 [00:00<00:00, 771.93it/s]
# Letra Capturada : O Hino
# fernandinho
# Letra Capturada : Caia Fogo
# fernandinho
# 100%|██████████| 6/6 [00:00<00:00, 3477.38it/s]
# Letra Capturada : Faz Chover
# fernandinho
# 100%|██████████| 8/8 [00:00<00:00, 1463.34it/s]
# 100%|██████████| 11/11 [00:00<00:00, 12163.81it/s]
# Letra Capturada : Galileu
# fernandinho
# Letra Capturada : Pra Sempre
# fernandinho
# 100%|██████████| 8/8 [00:00<00:00, 7936.24it/s]
# 100%|██████████| 11/11 [00:00<00:00, 12186.30it/s]
# Letra Capturada : Yeshua
# fernandinho
# Letra Capturada : Eu Jamais Serei o Mesmo
# Obtendo links/músicas
# roupa-nova
# 100%|██████████| 12/12 [00:00<00:00, 12589.21it/s]
# Letra Capturada : Meu Universo É Você
# roupa-nova
# 100%|██████████| 7/7 [00:00<00:00, 1410.53it/s]
# Letra Capturada : Linda Demais
# roupa-nova
# 100%|██████████| 9/9 [00:00<00:00, 6097.36it/s]
# 100%|██████████| 7/7 [00:00<00:00, 6452.78it/s]
# Letra Capturada : A Paz (part. Padre Fábio de Melo)
# roupa-nova
# Letra Capturada : Sapato Velho
# roupa-nova
# 100%|██████████| 10/10 [00:00<00:00, 12136.30it/s]
# 100%|██████████| 9/9 [00:00<00:00, 4419.71it/s]
# Letra Capturada : A Paz
# roupa-nova
# Letra Capturada : Volta Pra Mim
# roupa-nova
# 100%|██████████| 5/5 [00:00<00:00, 4526.55it/s]
# Letra Capturada : Anjo
# roupa-nova
# 100%|██████████| 4/4 [00:00<00:00, 3147.10it/s]
# Letra Capturada : Começo, Meio E Fim
# roupa-nova
# 100%|██████████| 8/8 [00:00<00:00, 22982.49it/s]
# Letra Capturada : Os Corações Não São Iguais
# roupa-nova
# 100%|██████████| 7/7 [00:00<00:00, 7408.56it/s]
# Letra Capturada : Amar É
# roupa-nova
# 100%|██████████| 14/14 [00:00<00:00, 37835.22it/s]
# Letra Capturada : Whisky a Go Go
# roupa-nova
# 100%|██████████| 10/10 [00:00<00:00, 10691.57it/s]
# Letra Capturada : Seguindo no Trem Azul
# roupa-nova
# 100%|██████████| 6/6 [00:00<00:00, 7137.22it/s]
# Letra Capturada : Natal Todo Dia
# roupa-nova
# 100%|██████████| 10/10 [00:00<00:00, 33261.73it/s]
# Letra Capturada : Dona
# roupa-nova
# 100%|██████████| 15/15 [00:00<00:00, 2789.14it/s]
# Letra Capturada : Um Sonho a Dois
# roupa-nova
# 100%|██████████| 8/8 [00:00<00:00, 15872.48it/s]
# Letra Capturada : Menina Veneno
# roupa-nova
# 100%|██████████| 10/10 [00:00<00:00, 20661.60it/s]
# Letra Capturada : Coração Pirata
# roupa-nova
# 100%|██████████| 10/10 [00:00<00:00, 10868.89it/s]
# 100%|██████████| 7/7 [00:00<00:00, 1114.96it/s]
# Letra Capturada : A Força do Amor
# roupa-nova
# Letra Capturada : Chuva de Prata (part. Sandy)
# roupa-nova
# 100%|██████████| 8/8 [00:00<00:00, 7005.10it/s]
# Letra Capturada : A Viagem
# Obtendo links/músicas
# legiao-urbana
# 100%|██████████| 7/7 [00:00<00:00, 22602.10it/s]
# 100%|██████████| 16/16 [00:00<00:00, 14983.00it/s]
# Letra Capturada : Giz
# legiao-urbana
# 100%|██████████| 6/6 [00:00<00:00, 6105.25it/s]
# Letra Capturada : Eduardo e Mônica
# legiao-urbana
# 100%|██████████| 9/9 [00:00<00:00, 30320.27it/s]
# Letra Capturada : Andrea Doria
# legiao-urbana
# Letra Capturada : Ainda É Cedo
# legiao-urbana
# 100%|██████████| 11/11 [00:00<00:00, 13070.07it/s]
# Letra Capturada : Pais e Filhos
# legiao-urbana
# 100%|██████████| 12/12 [00:00<00:00, 11803.86it/s]
# Letra Capturada : Perfeição
# legiao-urbana
# 100%|██████████| 8/8 [00:00<00:00, 7790.67it/s]
# 100%|██████████| 9/9 [00:00<00:00, 10311.05it/s]
# Letra Capturada : Quase Sem Querer
# legiao-urbana
# 100%|██████████| 6/6 [00:00<00:00, 6655.86it/s]
# Letra Capturada : Monte Castelo
# legiao-urbana
# 100%|██████████| 5/5 [00:00<00:00, 8137.96it/s]
# Letra Capturada : Hoje a Noite Não Tem Luar
# legiao-urbana
# Letra Capturada : Será
# legiao-urbana
# 100%|██████████| 14/14 [00:00<00:00, 44756.29it/s]
# Letra Capturada : Índios
# legiao-urbana
# 100%|██████████| 43/43 [00:00<00:00, 23428.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 2042.81it/s]
# Letra Capturada : Faroeste Caboclo
# legiao-urbana
# Letra Capturada : Há Tempos
# legiao-urbana
# 100%|██████████| 8/8 [00:00<00:00, 6340.60it/s]
# Letra Capturada : O Teatro dos Vampiros
# legiao-urbana
# 100%|██████████| 8/8 [00:00<00:00, 8274.83it/s]
# Letra Capturada : Que País É Este
# legiao-urbana
# 100%|██████████| 6/6 [00:00<00:00, 1180.11it/s]
# 100%|██████████| 9/9 [00:00<00:00, 1716.63it/s]
# Letra Capturada : Vento No Litoral
# legiao-urbana
# Letra Capturada : Os Bons Morrem Jovens
# legiao-urbana
# 100%|██████████| 7/7 [00:00<00:00, 7062.82it/s]
# Letra Capturada : Eu Sei
# legiao-urbana
# 100%|██████████| 13/13 [00:00<00:00, 15619.01it/s]
# Letra Capturada : Metal Contra as Nuvens
# legiao-urbana
# 100%|██████████| 10/10 [00:00<00:00, 5639.02it/s]
# Letra Capturada : Tempo Perdido
# Obtendo links/músicas
# guns-n-roses
# 100%|██████████| 10/10 [00:00<00:00, 6225.77it/s]
# 100%|██████████| 13/13 [00:00<00:00, 13344.58it/s]
# Letra Capturada : Don't Cry
# guns-n-roses
# Letra Capturada : You Could Be Mine
# guns-n-roses
# 100%|██████████| 9/9 [00:00<00:00, 11244.78it/s]
# 100%|██████████| 10/10 [00:00<00:00, 2070.65it/s]
# Letra Capturada : Estranged
# guns-n-roses
# Letra Capturada : Welcome To The Jungle
# guns-n-roses
# 100%|██████████| 7/7 [00:00<00:00, 7308.97it/s]
# Letra Capturada : Rocket Queen
# guns-n-roses
# 100%|██████████| 13/13 [00:00<00:00, 13948.82it/s]
# 100%|██████████| 5/5 [00:00<00:00, 3302.60it/s]
# Letra Capturada : Paradise City
# guns-n-roses
# Letra Capturada : Live And Let Die
# guns-n-roses
# 100%|██████████| 10/10 [00:00<00:00, 11538.66it/s]
# Letra Capturada : Knockin' On Heaven's Door
# guns-n-roses
# 100%|██████████| 17/17 [00:00<00:00, 10465.75it/s]
# Letra Capturada : Civil War
# guns-n-roses
# 100%|██████████| 12/12 [00:00<00:00, 6729.73it/s]
# Letra Capturada : It's So Easy
# guns-n-roses
# 100%|██████████| 10/10 [00:00<00:00, 3396.20it/s]
# 100%|██████████| 9/9 [00:00<00:00, 4671.87it/s]
# Letra Capturada : This I Love
# guns-n-roses
# 100%|██████████| 13/13 [00:00<00:00, 11866.37it/s]
# Letra Capturada : Used To Love Her
# guns-n-roses
# Letra Capturada : Mr. Brownstone
# guns-n-roses
# 100%|██████████| 14/14 [00:00<00:00, 7809.58it/s]
# 100%|██████████| 7/7 [00:00<00:00, 3690.78it/s]
# Letra Capturada : November Rain
# guns-n-roses
# 100%|██████████| 10/10 [00:00<00:00, 8516.35it/s]
# Letra Capturada : Yesterdays
# guns-n-roses
# 100%|██████████| 10/10 [00:00<00:00, 24385.49it/s]
# Letra Capturada : Patience
# guns-n-roses
# 100%|██████████| 11/11 [00:00<00:00, 10533.64it/s]
# Letra Capturada : Nightrain
# guns-n-roses
# Letra Capturada : So Fine
# guns-n-roses
# 100%|██████████| 12/12 [00:00<00:00, 9204.76it/s]
# Letra Capturada : Sweet Child O' Mine
# guns-n-roses
# 100%|██████████| 6/6 [00:00<00:00, 7724.32it/s]
# Letra Capturada : Since I Don't Have You
# Obtendo links/músicas
# aerosmith
# 100%|██████████| 7/7 [00:00<00:00, 20082.17it/s]
# 100%|██████████| 11/11 [00:00<00:00, 10873.76it/s]
# Letra Capturada : Jaded
# aerosmith
# Letra Capturada : Amazing
# aerosmith
# 100%|██████████| 17/17 [00:00<00:00, 7583.83it/s]
# 100%|██████████| 6/6 [00:00<00:00, 5186.69it/s]
# Letra Capturada : Fly Away from Here
# aerosmith
# Letra Capturada : Sweet Emotion
# aerosmith
# 100%|██████████| 12/12 [00:00<00:00, 7848.38it/s]
# Letra Capturada : (Water Song) Janie's Got a Gun
# aerosmith
# 100%|██████████| 17/17 [00:00<00:00, 5207.65it/s]
# 100%|██████████| 11/11 [00:00<00:00, 33849.85it/s]
# Letra Capturada : I Don't Want To Miss a Thing
# aerosmith
# 100%|██████████| 9/9 [00:00<00:00, 33435.55it/s]
# Letra Capturada : Cryin'
# aerosmith
# Letra Capturada : Dream On
# aerosmith
# 100%|██████████| 7/7 [00:00<00:00, 27084.99it/s]
# Letra Capturada : Pink
# aerosmith
# 100%|██████████| 17/17 [00:00<00:00, 9119.22it/s]
# Letra Capturada : Falling in Love (Is Hard on the Knees)
# aerosmith
# 100%|██████████| 10/10 [00:00<00:00, 11781.75it/s]
# 100%|██████████| 6/6 [00:00<00:00, 12433.71it/s]
# Letra Capturada : Hole in My Soul
# aerosmith
# Letra Capturada : Angel
# aerosmith
# 100%|██████████| 10/10 [00:00<00:00, 7364.89it/s]
# Letra Capturada : What It Takes
# aerosmith
# 100%|██████████| 16/16 [00:00<00:00, 7553.05it/s]
# Letra Capturada : Livin' On The Edge
# aerosmith
# 100%|██████████| 14/14 [00:00<00:00, 12269.17it/s]
# 100%|██████████| 15/15 [00:00<00:00, 1223.00it/s]
# Letra Capturada : Dude (Looks Like a Lady)
# aerosmith
# Letra Capturada : Girls of Summer
# aerosmith
# 100%|██████████| 18/18 [00:00<00:00, 33992.56it/s]
# Letra Capturada : What Could Have Been Love
# aerosmith
# 100%|██████████| 12/12 [00:00<00:00, 14463.12it/s]
# Letra Capturada : Walk This Way
# aerosmith
# 100%|██████████| 21/21 [00:00<00:00, 60453.25it/s]
# Letra Capturada : Full Circle
# aerosmith
# 100%|██████████| 15/15 [00:00<00:00, 6826.67it/s]
# Letra Capturada : Crazy
